# %% [markdown]
# # Learn Gate
#
# Learn Gate uses Short Memory to infer about one prediction
#
# ![Screen%20Shot%202018-11-19%20at%203.28.14%20PM.png](attachment:Screen%20Shot%202018-11-19%20at%203.28.14%20PM.png)
#
# **Learn Gate Function**
# ![screen-shot-2017-11-16-at-4.26.22-pm.png](attachment:screen-shot-2017-11-16-at-4.26.22-pm.png)
#
# # Forget Gate
#
# Decides what parts of the long term memory take
#
# ![Screen%20Shot%202018-11-19%20at%203.32.05%20PM.png](attachment:Screen%20Shot%202018-11-19%20at%203.32.05%20PM.png)
#
# **Forget Gate Function**
#
# ![screen-shot-2017-11-16-at-4.27.58-pm.png](attachment:screen-shot-2017-11-16-at-4.27.58-pm.png)
#
# # Remember Gate
#
# Takes which elements to remember from the short memory and add them to the long term
#
# ![Screen%20Shot%202018-11-19%20at%203.34.07%20PM.png](attachment:Screen%20Shot%202018-11-19%20at%203.34.07%20PM.png)
#
# ![Screen%20Shot%202018-11-19%20at%203.34.27%20PM.png](attachment:Screen%20Shot%202018-11-19%20at%203.34.27%20PM.png)
